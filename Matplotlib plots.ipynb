# %%
# This file is for plotting the results obtained
import numpy as np
import matplotlib.pyplot as plt

# %%
# Round 1 Training Loss VS Validation Loss Densenet201

train_loss = np.array([0.6836,0.2231,0.1661,0.1354,0.1157,0.1004,0.0904,0.0809,0.0673,0.0656,0.0660,0.0626,0.0622,0.0549,0.0480,0.0469,0.0459,0.0467,0.0392,0.0375,0.0388,0.0349,0.0363,0.0384,0.0342,0.0310,0.0303,0.0328,0.0325,0.0279]).astype(np.double) 
val_loss = np.array([0.4583,0.6642,0.4288,0.7661,0.3823,0.4532,0.5740,0.4199,0.7068,0.5703,0.9273,0.6515,0.6385,0.8661,1.3336,0.6907,0.9107,0.6632,0.5820,0.9403,0.8017,0.9497,2.6517,0.8698,0.9897,0.9312,1.3247,7.2769,1.0980,0.8142]).astype(np.double)

xlabel = []
for i in range(30):
    xlabel.append(str(i+1))
#xlabel = ['Resnet50', 'Resnet101', 'Resnet152', 'EfficientNet-B5', 'EfficientNet-B6', 'EfficientNet-B7', 'SE_Resnet101', 'SENet154', 'InceptionResnetV2'] 
# xs = np.arange(9) 
# dlmask = np.isfinite(deeplab) 
# fpnmask = np.isfinite(fpn)

plt.figure(figsize = (20, 10)) 
plt.plot(xlabel, train_loss , "o-", label = 'Training Loss') 
plt.plot(xlabel, val_loss , "o-", label = 'Validation Loss') 
plt.xlabel("Epochs") 
plt.ylabel("Loss") 
plt.legend(loc="upper left") 
plt.rc('font', size=15) 
plt.title('Round 1 Best Model (Densenet201) Training and Validation Loss')
plt.show()

# %%
# Round 1 Validation Accuracies

val_acc = np.array([0.9410,0.9406,0.8926,0.9326,0.9438,0.9477]).astype(np.double) 


xlabel = ['Resnet50', 'Resnet152', 'VGG16', 'VGG19', 'Densenet121', 'Densenet201'] 
# xs = np.arange(9) 
# dlmask = np.isfinite(deeplab) 
# fpnmask = np.isfinite(fpn)

plt.figure(figsize = (20, 12)) 
plt.plot(xlabel, val_acc , "o-", label = 'Validation Accuracy') 
plt.xlabel("Epochs") 
plt.ylabel("Accuracy") 
plt.legend(loc="lower right") 
plt.rc('font', size=35) 
plt.title('Round 1 Validation Accuracies')
plt.show()

# %%
# Round 2 Densenet 121 Validation Accuracies

val_acc = np.array([0.9438, 0.2598, 0.8801, 0.9218, 0.9389, 0.9094]).astype(np.double) 


xlabel = ['RMSProp','Adadelta', 'Adagrad', 'Adam', 'Adamax', 'SGD'] 
# xs = np.arange(9) 
# dlmask = np.isfinite(deeplab) 
# fpnmask = np.isfinite(fpn)

plt.figure(figsize = (20, 12)) 
plt.plot(xlabel, val_acc , "o-", label = 'Validation Accuracy') 
plt.xlabel("Epochs") 
plt.ylabel("Loss") 
plt.legend(loc="lower right") 
plt.rc('font', size=25) 
plt.title('Round 2 Densenet 121 Validation Accuracies')
plt.show()

# %%
# Round 2 Densenet 201 Validation Accuracies

val_acc = np.array([0.9477, 0.3754, 0.9207, 0.9486, 0.9432, 0.9172]).astype(np.double) 


xlabel = ['RMSProp','Adadelta', 'Adagrad', 'Adam', 'Adamax', 'SGD'] 
# xs = np.arange(9) 
# dlmask = np.isfinite(deeplab) 
# fpnmask = np.isfinite(fpn)

plt.figure(figsize = (20, 12)) 
plt.plot(xlabel, val_acc , "o-", label = 'Validation Accuracy') 
plt.xlabel("Epochs") 
plt.ylabel("Loss") 
plt.legend(loc="lower right") 
plt.rc('font', size=25) 
plt.title('Round 2 Densenet 201 Validation Accuracies')
plt.show()

# %%
# Round 3 Hyperparameter Tuning Accuracies

val_acc = np.array([0.9286, 0.9379, 0.9431, 0.9477, 0.9466]).astype(np.double) 


xlabel = ['LR=0.005','Beta 1=0.95', 'Epsilon=0.1', 'Epsilon=1', 'Beta 1=0.95,Epsilon=1'] 
# xs = np.arange(9) 
# dlmask = np.isfinite(deeplab) 
# fpnmask = np.isfinite(fpn)

plt.figure(figsize = (20, 12)) 
plt.plot(xlabel, val_acc , "o-", label = 'Validation Accuracy') 
plt.xlabel("Epochs") 
plt.ylabel("Loss") 
plt.legend(loc="lower right") 
plt.rc('font', size=25) 
plt.title('Round 3 Hyperparameter Tuning Validation Accuracies')
plt.show()

# %%
# Round 2 Training Loss VS Validation Loss Densenet201

train_loss = np.array([0.7310,0.2015,0.1436,0.1288,0.1117,0.1118,0.0818,0.0817,0.0775,0.0645,0.0634,0.0532,0.0567,0.0505,0.0441,0.0440,0.0343,0.0440,0.0355,0.0275,0.0260,0.0337,0.0245,0.0275,0.0301,0.0250,0.0102,0.0067,0.0067,0.0075]).astype(np.double) 
val_loss = np.array([0.3467,0.3395,0.3602,0.3607,0.3942,0.5468,0.4305,0.3793,0.4573,0.3470,0.3678,0.4089,0.3261,0.3829,0.3658,0.4755,0.4833,0.3914,0.4401,0.4409,0.6362,0.4766,0.5724,0.4201,0.6046,0.4654,0.4905,0.4841,0.4719,0.5746]).astype(np.double)

xlabel = []
for i in range(30):
    xlabel.append(str(i+1))


plt.figure(figsize = (20, 10)) 
plt.plot(xlabel, train_loss , "o-", label = 'Training Loss') 
plt.plot(xlabel, val_loss , "o-", label = 'Validation Loss') 
plt.xlabel("Epochs") 
plt.ylabel("Loss") 
plt.legend(loc="upper left") 
plt.rc('font', size=15) 
plt.title('Round 2 Best Model (Densenet201 Adam) Training and Validation Loss')
plt.show()

# %%
# Round 2 Training Loss VS Validation Loss Densenet121 
 
train_loss = np.array([1.5485,0.4006,0.2288,0.1545,0.1137,0.0908,0.0702,0.0583,0.0476,0.0398,0.0352,0.0304,0.0252,0.0246,0.0212,0.0178,0.0167,0.0154,0.0143,0.0124,0.0138,0.0121,0.0103,0.0075,0.0098,0.0093,0.0078,0.006,0.0039,0.0042]).astype(np.double)  
val_loss = np.array([0.5645,0.3517,0.3147,0.2775,0.2893,0.2820,0.2828,0.3073,0.2889,0.2947,0.2851,0.3212,0.3359,0.3131,0.3250,0.3595,0.3308,0.3446,0.3435,0.3588,0.3614,0.3617,0.3795,0.3884,0.3706,0.3667,0.3903,0.4008,0.4091,0.4104]).astype(np.double) 
 
print(len(train_loss))
print(len(val_loss))
xlabel = [] 
for i in range(30): 
    xlabel.append(str(i+1)) 
 
 
plt.figure(figsize = (20, 10))  
plt.plot(xlabel, train_loss , "o-", label = 'Training Loss')  
plt.plot(xlabel, val_loss , "o-", label = 'Validation Loss')  
plt.xlabel("Epochs")  
plt.ylabel("Loss")  
plt.legend(loc="upper left")  
plt.rc('font', size=15)  
plt.title('Round 2 Best Model (Densenet121 Adamax) Training and Validation Loss')
# Out:
# 30
# 30
# Text(0.5, 1.0, 'Round 2 Best Model (Densenet121 Adamax) Training and Validation Loss')

# %%
# Round 3 Training Loss VS Validation Loss Densenet201 
 
train_loss = np.array([3.2124,1.2509, 0.6036,0.3859,0.2756,0.2174, 0.1766, 0.1496, 0.1306, 0.1083, 0.0958,0.0837,0.0717,0.0676,0.0604,0.0536, 0.0489,0.0442,0.0422,0.0401,0.0383,0.0333,0.0308,0.0285,0.0272,0.0252,0.0222,0.0219,0.0203,0.0178]).astype(np.double)  
val_loss = np.array([1.8125,0.6981,0.4361,0.3462,0.3005,0.2753,0.2594,0.2595,0.2582,0.2711,0.2661,0.2609,0.2568,0.2690,0.2713,0.2701,0.2753,0.2583,0.2655,0.2651,0.2691,0.2791,0.2780,0.2880,0.2904,0.297,0.2887,0.3038,0.2931,0.3106 ]).astype(np.double) 

print(len(train_loss))
print(len(val_loss))
      
xlabel = [] 
for i in range(30): 
    xlabel.append(str(i+1)) 
 
 
plt.figure(figsize = (20, 10))  
plt.plot(xlabel, train_loss , "o-", label = 'Training Loss')  
plt.plot(xlabel, val_loss , "o-", label = 'Validation Loss')  
plt.xlabel("Epochs")  
plt.ylabel("Loss")  
plt.legend(loc="upper left")  
plt.rc('font', size=15)  
plt.title('Round 3 Best Model (Densenet201 Adam Epsilon 1) Training and Validation Loss') 
plt.show()
# Out:
# 30
# 30

# %%
# Round 4 Training Loss VS Validation Loss Densenet201 
 
train_loss = np.array([3.6695,1.9717,1.0337,0.6827,0.5127,0.4231,0.3609,0.3162,0.2874,0.2601,0.2423,0.2186,0.2004,0.1898,0.1825,0.1701,0.1629,0.1545,0.1456,0.142,0.1319,0.1296,0.1276,0.1221,0.1131,0.1121,0.1082,0.1057,0.1031,0.1003]).astype(np.double)  
val_loss = np.array([2.6044,1.1701,0.6483,0.4695,0.3995,0.3353,0.2983,0.2913,0.2707,0.2740,0.2820,0.2754,0.2722,0.2706,0.2586,0.2602,0.2543,0.2463,0.2647,0.2580,0.2552,0.2554,0.2598,0.2497,0.2510,0.2494,0.2631,0.2532,0.2583, 0.2465 ]).astype(np.double) 
 
print(len(train_loss))
print(len(val_loss))
xlabel = [] 
for i in range(30): 
    xlabel.append(str(i+1)) 
 
 
plt.figure(figsize = (20, 10))  
plt.plot(xlabel, train_loss , "o-", label = 'Training Loss')  
plt.plot(xlabel, val_loss , "o-", label = 'Validation Loss')  
plt.xlabel("Epochs")  
plt.ylabel("Loss")  
plt.legend(loc="upper left")  
plt.rc('font', size=15)  
plt.title('Round 4 Best Model (Densenet201 Adam Epsilon 1 with Rotation) Training and Validation Loss') 
plt.show()
# Out:
# 30
# 30
